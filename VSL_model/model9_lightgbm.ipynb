# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# %matplotlib inline
import  matplotlib.pyplot as plt

# %%
train= pd.read_excel('../dataset/pre_train.xlsx')
test= pd.read_excel('../dataset/pre_test.xlsx')

# %%
train.shape
# Out:
# (14208, 18)

# %%
train.describe()
# Out:
#                WI_F          WI_T        WI_COD         WI_TN         WI_AN  \
# count  14208.000000  14208.000000  14208.000000  14208.000000  14208.000000
# mean    1683.382025     27.813829    184.842024     35.791522     27.364368
# std      523.260353      1.013008     55.271241      6.002742      5.126412
# min      217.916363     24.517528     86.577400     17.430883     11.997580
# 25%     1199.022153     26.990108    146.412000     31.998785     23.677716
# 50%     1793.830473     27.918017    170.347500     36.298490     28.359787
# 75%     2127.908596     28.646956    213.671800     39.623632     31.143964
# max     3259.585664     30.095026    396.867000     69.558763     37.038204
#
#                WO_F          WO_T        WO_COD         WO_TN         WO_AN  \
# count  14208.000000  14208.000000  14208.000000  14208.000000  14208.000000
# mean    1547.411837     28.250495      6.228537     10.069905      0.031830
# std      598.330524      1.290882      1.677227      1.608902      0.110762
# min       47.077030     25.850362      1.093400      0.881280      0.001093
# 25%     1139.269904     27.006044      5.522000      8.979977      0.010757
# 50%     1531.360528     28.679910      6.432000     10.122684      0.015721
# 75%     1958.713239     29.467961      7.256200     11.203871      0.029753
# max     3320.082757     30.162999     18.309200     13.514503      1.476282
#
#             AR_MLSS         AR_AN         AR_NN       AR_WIDO       AR_WODO  \
# count  14208.000000  14208.000000  14208.000000  14208.000000  14208.000000
# mean    5969.336794      0.201977      8.043728      0.382990      1.282218
# std      228.335802      0.006275      1.632819      0.117482      0.700147
# min     5273.518511      0.186971      2.419740      0.002295      0.248452
# 25%     5816.183677      0.197306      7.056788      0.300399      0.786313
# 50%     5967.349452      0.202002      8.196378      0.385052      1.111968
# 75%     6112.247880      0.206661      9.218385      0.465928      1.596545
# max     6731.656344      0.216031     14.374467      0.937521      4.745541
#
#                AR_F            AQ
# count  14208.000000  14208.000000
# mean    4399.123510  14320.010701
# std       18.567990   3768.076988
# min     4352.285757   3293.049760
# 25%     4383.718223  11785.515967
# 50%     4398.890688  13894.344580
# 75%     4414.653484  16011.438310
# max     4441.656493  31900.870400

# %%
ind=[i for i in train.columns][1:-1]
# ind=['WI_F',
#  'WI_T',
#  'WI_COD',
#  'WI_TN',
#  'WI_AN',
#  'WO_F',
#  'WO_T',
#  'WO_COD',
#  'WO_TN',
#  'WO_AN',
#  'AR_MLSS',
#  'AR_AN',
#  'AR_NN',
#  'AR_WIDO',
#  'AR_WODO',
#  'AR_F']
#1  离群点删除
def opt(opt_rate,df,threshold):
    AQindex=[]
    train=df
    threshold_num=threshold*len(df)
    for inx in ind:
        max=train.loc[:, inx].max()
        min=train.loc[:, inx].min()
        diff=max-min
        diffmin=min+opt_rate*diff
        diffmax=min+(1-opt_rate)*diff
        minlist=train[train[inx] < diffmin].index.values.tolist()
        maxlist=train[train[inx] > diffmax].index.values.tolist()

        if len(minlist) <= threshold_num:
            # print(f'min{inx}')
            # print(len(minlist))
            for minindex in train[train[inx] < diffmin].index.values.tolist():
                AQindex.append(minindex)

        if len(maxlist) <= threshold_num:
            # print(f'max{inx}')
            # print(len(maxlist))
            for maxindex in train[train[inx] > diffmax].index.values.tolist():
                AQindex.append(maxindex)
    AQindex=list(set(AQindex))
    # print(AQindex)
    AQindex=sorted(AQindex)
    return AQindex
optindex=opt(opt_rate=0.1,df=train,threshold=0.015)
train=train.drop(index=optindex).reset_index(drop=True)

# %%
train.shape
# train.describe()
# Out:
# (12712, 18)

# %%
data = pd.concat([train,test]).reset_index(drop=True)

# %%
#2  时间特征
def add_datetime_feats(df):
    df['time'] = pd.to_datetime(df['time'])
    # df['year']=df['year'].dt.year  # 获取年
    # df['month']=df['month'].dt.month  # 获取月
    # df['day'] = df['time'].dt.day       # 获取天
    df['hour'] = df['time'].dt.hour
    df['minute']=df['time'].dt.minute  # 获取分钟
    df['weekday']=df['time'].dt.weekday
    df['ts']=df['hour']*60+df['minute']  # 判断是一年的第几个季度
    return df


data= add_datetime_feats(data)

# %%
data.shape
# Out:
# (13192, 22)

# %%
#3 去除率指标
data['Var_COD']=data['WI_COD']-data['WO_COD']
data['Var_AN']=(data['WI_AN']-data['WO_AN'])
data['Var_TN']=(data['WI_TN']-data['WO_TN'])
data['Var_AR_DO']=data['AR_WODO']-data['AR_WIDO']
data['Var_AR_AN']=(data['WI_AN']-data['AR_AN'])


data['RM_COD']=(data['WI_COD']-data['WO_COD'])/data['WI_COD']
data['RM_AN']=(data['WI_AN']-data['WO_AN'])/data['WI_AN']
data['RM_TN']=(data['WI_TN']-data['WO_TN'])/data['WI_TN']
data['RM_AR_DO']=(data['AR_WODO']-data['AR_WIDO'])/data['AR_WODO']
data['RM_AR_AN']=(data['WI_AN']-data['AR_AN'])/data['WI_AN']

# %%
data.shape
# Out:
# (13192, 32)

# %%
#4 时序上的滚动特征
roll_cols = ['WI_F',
 'WI_T',
 'WI_COD',
 'WI_TN',
 'WI_AN',
 'WO_F',
 'WO_T',
 'WO_COD',
 'WO_TN',
 'WO_AN',
 'AR_MLSS',
 'AR_AN',
 'AR_NN',
 'AR_WIDO',
 'AR_WODO',
 'AR_F']
for i in [j for j in range(1, 6)] + [10, 15, 20, 30, 60, 120]:
    # data[[ii+f'_delta_{i}' for ii in roll_cols]] = data[roll_cols].diff(periods=i)
    data[[ii+f'_mean_{i}' for ii in roll_cols]] = data[roll_cols].rolling(i, min_periods=1).mean()
# df[[ii+'_roll_8_mean' for ii in roll_cols]] = df[roll_cols].rolling(8, min_periods=1).mean()
# df[[ii+'_roll_16_mean' for ii in roll_cols]] = df[roll_cols].rolling(16, min_periods=1).mean()
#
# df[[ii+'_roll_16_mean_diff' for ii in roll_cols]] = df[[ii+'_roll_16_mean' for ii in roll_cols]].diff()
# df[[ii+'_roll_8_mean_diff' for ii in roll_cols]] = df[[ii+'_roll_8_mean' for ii in roll_cols]].diff()
#
# df[[ii+'_roll_8_std' for ii in roll_cols]] = df[roll_cols].rolling(8, min_periods=1).std()

# %%
data.shape
# Out:
# (13192, 208)

# %%
#根据方差只保留save_rate的特征数量
pd.set_option("display.max_columns", 100)
save_rate = 0.8
data = data[data.describe().T.sort_values(by="std", ascending=False, inplace=False).iloc[: int(len(data.columns)*save_rate)].index.tolist()]

# %%
# data.describe()

# %%
train = data.iloc[:train.shape[0]].reset_index(drop=True)
test = data.iloc[train.shape[0]:].reset_index(drop=True)
print(train.shape)
# Out:
# (12712, 166)

# %%
X_columns = [col for col in train.columns if col not in ['time','AQ','hour','minute','weekday','ts']]
Y_columns =['AQ']

# %%
# X_columns

# %%
x_train=train[X_columns]
y_train=train[Y_columns]
x_test=test[X_columns]
y_test=test[Y_columns]

# %%
# # target log1p 转换`
# train['AQ'] = np.log1p(train['AQ'])

# %%
import lightgbm as lgb
from sklearn.metrics import mean_absolute_percentage_error
import gc
from tscv import GapKFold

params = {'boosting_type': 'gbdt',
          'objective': 'regression',
          'min_data_in_leaf': 16,
          'min_gain_to_split': 0.379,
          'metric': 'mape',
          'num_leaves': 32,
          'max_depth': 31,
          'learning_rate': 0.01,
          'n_estimators': 1200,
          'subsample': 0.8,
          'feature_fraction': 0.70,
          'lambda_l1': 2.7586206896551726,
          'lambda_l2': 9.655172413793103,
          'random_state': 2022,
          'device': 'gpu',
          'gpu_platform_id': 1,
          'gpu_device_id': 0}
folds = GapKFold(n_splits=10)
oof = np.zeros(len(train))
predictions = np.zeros(len(test))
feature_importance_df = pd.DataFrame()

# %%
test[Y_columns].shape
# Out:
# (480, 1)

# %%
print('Starting training...')
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train[X_columns])):
        print("fold {}".format(fold_+1))
        X_train = train.iloc[trn_idx][X_columns]
        Y_train = train.iloc[trn_idx][Y_columns]
        X_val = train.iloc[val_idx][X_columns]
        Y_val = train.iloc[val_idx][Y_columns]
        trn_data = lgb.Dataset(X_train, Y_train)
        val_data = lgb.Dataset(X_val, Y_val)


        clf = lgb.train(params,
                        trn_data,
                        valid_sets = [trn_data, val_data],
                        verbose_eval=100,
                        early_stopping_rounds = 100)


        oof[val_idx] = np.expm1(clf.predict(train.iloc[val_idx][X_columns], num_iteration=clf.best_iteration))

        fold_importance_df = pd.DataFrame()
        fold_importance_df["Feature"] = X_columns
        fold_importance_df["importance"] = clf.feature_importance()
        fold_importance_df["fold"] = fold_ + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

        predictions += clf.predict(test[X_columns], num_iteration=clf.best_iteration) / folds.n_splits
        # predictions += np.expm1(clf.predict(test[X_columns], num_iteration=clf.best_iteration)) / folds.n_splits


print('The mape of prediction is:', mean_absolute_percentage_error(test[Y_columns], predictions))
# Out:
# Starting training...
# fold 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 41310
# [LightGBM] [Info] Number of data points in the train set: 11440, number of used features: 162
# [LightGBM] [Info] Using requested OpenCL platform 1 device 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 162 dense feature groups (1.79 MB) transferred to GPU in 0.013827 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14224.499491
# Training until validation scores don't improve for 100 rounds
# [100]	training's mape: 0.107752	valid_1's mape: 0.134132
# [200]	training's mape: 0.071751	valid_1's mape: 0.127039
# [300]	training's mape: 0.0545536	valid_1's mape: 0.119418
# [400]	training's mape: 0.0457562	valid_1's mape: 0.113328
# [500]	training's mape: 0.040882	valid_1's mape: 0.109651
# [600]	training's mape: 0.0375014	valid_1's mape: 0.10773
# [700]	training's mape: 0.0350735	valid_1's mape: 0.106485
# [800]	training's mape: 0.0331462	valid_1's mape: 0.105638
# [900]	training's mape: 0.031594	valid_1's mape: 0.104897
# [1000]	training's mape: 0.0303035	valid_1's mape: 0.104463
# [1100]	training's mape: 0.029136	valid_1's mape: 0.104204
# [1200]	training's mape: 0.0281155	valid_1's mape: 0.103795
# Did not meet early stopping. Best iteration is:
# [1200]	training's mape: 0.0281155	valid_1's mape: 0.103795
# fold 2
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 41310
# [LightGBM] [Info] Number of data points in the train set: 11440, number of used features: 162
# [LightGBM] [Info] Using requested OpenCL platform 1 device 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 162 dense feature groups (1.79 MB) transferred to GPU in 0.013068 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14160.970433
# Training until validation scores don't improve for 100 rounds
# [100]	training's mape: 0.1068	valid_1's mape: 0.133287
# [200]	training's mape: 0.0712701	valid_1's mape: 0.112765
# [300]	training's mape: 0.0542643	valid_1's mape: 0.103038
# [400]	training's mape: 0.0455788	valid_1's mape: 0.0978719
# [500]	training's mape: 0.040658	valid_1's mape: 0.0957669
# [600]	training's mape: 0.0374727	valid_1's mape: 0.0945452
# [700]	training's mape: 0.0351176	valid_1's mape: 0.0940628
# [800]	training's mape: 0.0332479	valid_1's mape: 0.0937405
# [900]	training's mape: 0.0316963	valid_1's mape: 0.093546
# [1000]	training's mape: 0.0303027	valid_1's mape: 0.093408
# [1100]	training's mape: 0.029074	valid_1's mape: 0.0933154
# [1200]	training's mape: 0.0279696	valid_1's mape: 0.0932064
# Did not meet early stopping. Best iteration is:
# [1200]	training's mape: 0.0279696	valid_1's mape: 0.0932064
# fold 3
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 41310
# [LightGBM] [Info] Number of data points in the train set: 11441, number of used features: 162
# [LightGBM] [Info] Using requested OpenCL platform 1 device 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 162 dense feature groups (1.79 MB) transferred to GPU in 0.013872 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14144.602889
# Training until validation scores don't improve for 100 rounds
# [100]	training's mape: 0.107282	valid_1's mape: 0.134377
# [200]	training's mape: 0.0717957	valid_1's mape: 0.108945
# [300]	training's mape: 0.0543004	valid_1's mape: 0.0976492
# [400]	training's mape: 0.0456934	valid_1's mape: 0.0919123
# [500]	training's mape: 0.0407716	valid_1's mape: 0.0889937
# [600]	training's mape: 0.0374543	valid_1's mape: 0.0875518
# [700]	training's mape: 0.0350815	valid_1's mape: 0.0869141
# [800]	training's mape: 0.0331762	valid_1's mape: 0.086576
# [900]	training's mape: 0.0316503	valid_1's mape: 0.0863429
# [1000]	training's mape: 0.0303514	valid_1's mape: 0.0861824
# [1100]	training's mape: 0.0291771	valid_1's mape: 0.0861654
# [1200]	training's mape: 0.0281034	valid_1's mape: 0.0860608
# Did not meet early stopping. Best iteration is:
# [1200]	training's mape: 0.0281034	valid_1's mape: 0.0860608
# fold 4
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 41310
# [LightGBM] [Info] Number of data points in the train set: 11441, number of used features: 162
# [LightGBM] [Info] Using requested OpenCL platform 1 device 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 162 dense feature groups (1.79 MB) transferred to GPU in 0.013604 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14005.873539
# Training until validation scores don't improve for 100 rounds
# [100]	training's mape: 0.1061	valid_1's mape: 0.129686
# [200]	training's mape: 0.0705707	valid_1's mape: 0.105748
# [300]	training's mape: 0.0539918	valid_1's mape: 0.0945845
# [400]	training's mape: 0.0454148	valid_1's mape: 0.0885834
# [500]	training's mape: 0.0405268	valid_1's mape: 0.0853022
# [600]	training's mape: 0.0372385	valid_1's mape: 0.0836169
# [700]	training's mape: 0.0347385	valid_1's mape: 0.0826257
# [800]	training's mape: 0.032884	valid_1's mape: 0.0822598
# [900]	training's mape: 0.0313436	valid_1's mape: 0.0820234
# [1000]	training's mape: 0.0300158	valid_1's mape: 0.0817532
# [1100]	training's mape: 0.0288709	valid_1's mape: 0.0815936
# [1200]	training's mape: 0.0278073	valid_1's mape: 0.0814031
# Did not meet early stopping. Best iteration is:
# [1200]	training's mape: 0.0278073	valid_1's mape: 0.0814031
# fold 5
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 41310
# [LightGBM] [Info] Number of data points in the train set: 11441, number of used features: 162
# [LightGBM] [Info] Using requested OpenCL platform 1 device 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 162 dense feature groups (1.79 MB) transferred to GPU in 0.014217 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14414.370646
# Training until validation scores don't improve for 100 rounds
# [100]	training's mape: 0.103718	valid_1's mape: 0.203405
# [200]	training's mape: 0.0697666	valid_1's mape: 0.159449
# [300]	training's mape: 0.0538137	valid_1's mape: 0.138367
# [400]	training's mape: 0.0455777	valid_1's mape: 0.128789
# [500]	training's mape: 0.0409185	valid_1's mape: 0.124875
# [600]	training's mape: 0.0377002	valid_1's mape: 0.123264
# [700]	training's mape: 0.0354015	valid_1's mape: 0.122415
# [800]	training's mape: 0.0335568	valid_1's mape: 0.122259
# [900]	training's mape: 0.0320448	valid_1's mape: 0.122264
# [1000]	training's mape: 0.0306952	valid_1's mape: 0.122109
# Early stopping, best iteration is:
# [979]	training's mape: 0.0309731	valid_1's mape: 0.122046
# fold 6
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 41310
# [LightGBM] [Info] Number of data points in the train set: 11441, number of used features: 162
# [LightGBM] [Info] Using requested OpenCL platform 1 device 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 162 dense feature groups (1.79 MB) transferred to GPU in 0.015112 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14513.184691
# Training until validation scores don't improve for 100 rounds
# [100]	training's mape: 0.108052	valid_1's mape: 0.156714
# [200]	training's mape: 0.0730914	valid_1's mape: 0.107834
# [300]	training's mape: 0.0561525	valid_1's mape: 0.0880022
# [400]	training's mape: 0.0474411	valid_1's mape: 0.0816386
# [500]	training's mape: 0.0424683	valid_1's mape: 0.0788522
# [600]	training's mape: 0.0391187	valid_1's mape: 0.0774434
# [700]	training's mape: 0.0367471	valid_1's mape: 0.0768946
# [800]	training's mape: 0.0349047	valid_1's mape: 0.0766143
# Early stopping, best iteration is:
# [790]	training's mape: 0.0350723	valid_1's mape: 0.0765642
# fold 7
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 41310
# [LightGBM] [Info] Number of data points in the train set: 11441, number of used features: 162
# [LightGBM] [Info] Using requested OpenCL platform 1 device 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 162 dense feature groups (1.79 MB) transferred to GPU in 0.014855 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14472.328910
# Training until validation scores don't improve for 100 rounds
# [100]	training's mape: 0.109479	valid_1's mape: 0.161101
# [200]	training's mape: 0.0734615	valid_1's mape: 0.133975
# [300]	training's mape: 0.0564645	valid_1's mape: 0.120752
# [400]	training's mape: 0.0474476	valid_1's mape: 0.112955
# [500]	training's mape: 0.0424144	valid_1's mape: 0.108538
# [600]	training's mape: 0.0391915	valid_1's mape: 0.106148
# [700]	training's mape: 0.0368058	valid_1's mape: 0.105228
# [800]	training's mape: 0.034919	valid_1's mape: 0.104735
# [900]	training's mape: 0.0333398	valid_1's mape: 0.104399
# [1000]	training's mape: 0.0319796	valid_1's mape: 0.104246
# [1100]	training's mape: 0.0307865	valid_1's mape: 0.103987
# [1200]	training's mape: 0.0297059	valid_1's mape: 0.103952
# Did not meet early stopping. Best iteration is:
# [1200]	training's mape: 0.0297059	valid_1's mape: 0.103952
# fold 8
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 41310
# [LightGBM] [Info] Number of data points in the train set: 11441, number of used features: 162
# [LightGBM] [Info] Using requested OpenCL platform 1 device 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 162 dense feature groups (1.79 MB) transferred to GPU in 0.012925 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14318.598730
# Training until validation scores don't improve for 100 rounds
# [100]	training's mape: 0.111715	valid_1's mape: 0.0799014
# [200]	training's mape: 0.0745496	valid_1's mape: 0.0671999
# [300]	training's mape: 0.0563801	valid_1's mape: 0.0637262
# [400]	training's mape: 0.0474299	valid_1's mape: 0.063582
# Early stopping, best iteration is:
# [337]	training's mape: 0.05231	valid_1's mape: 0.0633762
# fold 9
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 41310
# [LightGBM] [Info] Number of data points in the train set: 11441, number of used features: 162
# [LightGBM] [Info] Using requested OpenCL platform 1 device 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 162 dense feature groups (1.79 MB) transferred to GPU in 0.014700 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14282.837116
# Training until validation scores don't improve for 100 rounds
# [100]	training's mape: 0.110133	valid_1's mape: 0.111003
# [200]	training's mape: 0.0733392	valid_1's mape: 0.100591
# [300]	training's mape: 0.0556515	valid_1's mape: 0.0955984
# [400]	training's mape: 0.0468949	valid_1's mape: 0.0933327
# [500]	training's mape: 0.0420176	valid_1's mape: 0.0923898
# [600]	training's mape: 0.0388633	valid_1's mape: 0.0920096
# [700]	training's mape: 0.0365179	valid_1's mape: 0.0913359
# [800]	training's mape: 0.034724	valid_1's mape: 0.0908759
# [900]	training's mape: 0.033187	valid_1's mape: 0.0905485
# [1000]	training's mape: 0.0318577	valid_1's mape: 0.0902294
# [1100]	training's mape: 0.0306478	valid_1's mape: 0.0902377
# Early stopping, best iteration is:
# [1018]	training's mape: 0.031624	valid_1's mape: 0.0901417
# fold 10
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 41310
# [LightGBM] [Info] Number of data points in the train set: 11441, number of used features: 162
# [LightGBM] [Info] Using requested OpenCL platform 1 device 0
# [LightGBM] [Info] Using GPU Device: NVIDIA GeForce RTX 3070 Laptop GPU, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 162 dense feature groups (1.79 MB) transferred to GPU in 0.014852 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 14201.373582
# Training until validation scores don't improve for 100 rounds
# [100]	training's mape: 0.109628	valid_1's mape: 0.0964781
# [200]	training's mape: 0.0725031	valid_1's mape: 0.091597
# [300]	training's mape: 0.0552394	valid_1's mape: 0.0894174
# [400]	training's mape: 0.0465129	valid_1's mape: 0.0877242
# [500]	training's mape: 0.0416432	valid_1's mape: 0.0865775
# [600]	training's mape: 0.0384271	valid_1's mape: 0.085973
# [700]	training's mape: 0.0360822	valid_1's mape: 0.0856362
# [800]	training's mape: 0.034257	valid_1's mape: 0.0856984
# Early stopping, best iteration is:
# [708]	training's mape: 0.0359136	valid_1's mape: 0.0856167
# The mape of prediction is: 0.06446066371200204

# %%
predictions.shape
# Out:
# (480,)

# %%
# test[['time','AQ']]

# %%
predictions
# Out:
# array([15747.41372105, 16112.7784198 , 16363.00498805, 16735.31436654,
#        16806.18505664, 16717.78003846, 16582.23797256, 16463.18783405,
#        16551.01814456, 16457.21138396, 16495.17987986, 16333.64307102,
#        16266.23296833, 16162.55039747, 16082.32949857, 16341.52373115,
#        16275.36502695, 15753.47312548, 15646.84162143, 15605.20180116,
#        15783.88803935, 15831.98168245, 15323.55545505, 15045.97611401,
#        15306.800705  , 15228.41568228, 15238.97639779, 15254.72022283,
#        15287.7637972 , 15282.75221163, 15263.96941375, 15226.57405313,
#        15268.99521765, 15264.45191934, 15027.4715867 , 15017.16902722,
#        15269.37136251, 15494.25766311, 15376.16292607, 15494.22837846,
#        15231.88715069, 15119.9240232 , 15062.06582806, 15091.01558388,
#        15314.50334604, 15517.64691173, 15642.53847938, 15708.30954564,
#        15761.94512691, 15876.50696824, 16484.57894808, 15963.4999206 ,
#        16119.63245202, 16151.39554029, 15965.54227657, 15885.05267615,
#        16128.48518225, 16212.00232857, 16039.87662259, 16619.28949924,
#        16608.88733648, 16038.90181163, 16040.17328494, 15797.2712281 ,
#        15688.29543444, 15637.02146642, 15318.02371437, 15327.6187299 ,
#        15149.49217184, 14860.11123282, 14856.10853046, 14954.98454032,
#        14935.11224784, 15045.71414425, 14924.73402438, 14909.92780987,
#        14998.84946979, 15037.52071734, 15048.13673666, 14690.66503887,
#        14606.43092812, 14973.4269759 , 14918.75385636, 14846.45078111,
#        15181.65985248, 15260.8407269 , 14733.01798515, 14953.75509495,
#        14911.98167475, 14823.38346373, 14911.85110996, 14813.25003457,
#        15001.04461171, 15216.34533307, 15352.06033279, 15409.24356624,
#        15287.75941087, 15634.8817769 , 15448.2674316 , 15350.99516695,
#        15840.09807356, 16022.34772267, 15876.17133871, 15909.52957825,
#        15983.56008259, 16159.97311975, 16499.12979332, 16971.35610458,
#        17126.05921922, 16888.79581602, 16633.14868549, 16275.82094444,
#        16375.83963822, 15745.35357972, 15323.56409799, 14896.40221896,
#        15601.126256  , 14560.92614194, 14444.93669692, 14228.43192852,
#        14159.33561557, 14124.55855106, 14055.5429717 , 13911.8316699 ,
#        14012.9325885 , 15619.27997412, 14111.49741891, 15027.72337261,
#        13900.46227629, 13720.73535669, 13557.67898301, 13573.37045791,
#        13733.59023163, 13869.30581355, 13803.71920559, 13825.9002286 ,
#        14087.97326498, 13856.58599794, 13815.87838208, 13674.03231858,
#        13142.62983166, 12472.19831194, 12414.61345152, 12482.57884148,
#        12913.87631824, 12762.86862066, 12617.96466825, 12509.10539896,
#        12471.44517847, 12477.60072814, 12456.09228504, 12452.22105642,
#        12456.25502836, 12487.31475393, 12580.29305878, 12484.20179892,
#        12612.16674603, 12736.38130724, 12829.88246686, 12871.01416169,
#        13011.53337738, 13028.2735437 , 13062.40038675, 13352.85665801,
#        14139.47471114, 14375.19487162, 14778.4926394 , 14372.67735645,
#        13614.52519359, 13640.14759072, 13683.09479321, 13640.53249083,
#        13715.75278975, 13950.06298724, 13217.59929406, 13248.28187973,
#        13159.41298933, 13579.41857642, 13541.77166584, 13446.39089497,
#        13387.51726255, 13084.27272741, 13299.79155646, 12919.18115421,
#        12812.29940138, 12789.88477854, 12667.72386503, 12565.14569055,
#        12690.93133217, 12684.91882703, 12544.02288366, 12459.95845937,
#        12357.23750733, 12277.39015044, 12234.94477546, 12193.15970248,
#        12151.03180555, 12182.21530267, 12145.49021232, 12144.00057729,
#        12090.90812919, 11850.26180132, 12017.67632733, 11937.66945684,
#        11893.93987333, 11887.72088783, 11882.62247246, 11870.24120395,
#        11863.9782333 , 11964.79749586, 11875.15167499, 11861.77265298,
#        11836.86808819, 11882.01441969, 11791.18769454, 11842.77831871,
#        11890.02141182, 11962.02786772, 12055.03701898, 12042.5342342 ,
#        11859.4176919 , 11853.72060645, 11855.27201157, 11888.77197573,
#        12076.74873287, 12074.59038002, 12193.11944657, 12286.94983042,
#        12214.09379064, 12270.36549875, 12301.49735882, 12438.59241771,
#        12698.26875211, 12579.71192651, 12418.42923609, 12443.92617548,
#        12461.458671  , 12660.49928984, 12613.76089421, 12694.62753152,
#        12588.50813688, 12486.67866875, 12568.25081047, 12673.18743811,
#        12677.8823836 , 12743.33704113, 12589.42747412, 12607.53091373,
#        12537.25770914, 12516.40939952, 12466.23803164, 12438.96282731,
#        12384.26434489, 12480.12434516, 12701.07653231, 12887.56986675,
#        12538.35641576, 12749.5328438 , 12845.0368089 , 12636.26295926,
#        12685.28706777, 12639.05522159, 12710.51983337, 12789.32097705,
#        12825.64148385, 12774.9570571 , 12769.85441812, 12847.1225278 ,
#        12899.69218484, 12951.31939698, 12818.44919324, 12846.34192851,
#        12683.31256029, 12614.99019313, 12652.41451369, 12662.39387619,
#        12667.21116007, 12671.89483704, 12713.67253333, 12631.35731044,
#        12707.04908506, 12798.76405589, 12809.20221983, 12772.48767186,
#        12904.90940106, 13046.77708426, 13039.62444774, 13128.01366195,
#        13157.70089926, 13214.56391958, 13267.61000158, 13445.85389511,
#        13768.5300476 , 13994.76709353, 13945.56914323, 13994.3483146 ,
#        14053.63484764, 14109.56168336, 14136.58645684, 13728.92101226,
#        13511.55981191, 13295.6166436 , 13309.6229734 , 13308.02313398,
#        13422.50116396, 13361.13116675, 13136.67954628, 13181.48082211,
#        13457.62113897, 13442.24467305, 13478.9609651 , 13501.90339761,
#        13786.09400326, 13750.18229705, 13727.62353586, 14057.42360175,
#        13778.66916901, 13881.87372115, 13933.82177517, 14000.6270885 ,
#        13905.01952091, 13878.75652956, 13699.53045921, 13593.45045874,
#        13932.4886123 , 14036.82004875, 14072.81796576, 14299.81411043,
#        14226.2661939 , 13820.93666695, 13303.09156284, 13507.221442  ,
#        13572.00291957, 13195.64302407, 13146.98087474, 13535.57882246,
#        13269.18544017, 13704.25636253, 14439.9504702 , 14936.81544768,
#        15506.0561337 , 15050.69139512, 15760.9984533 , 16029.32212656,
#        16293.12542343, 16000.20444115, 15641.73154399, 15449.20453314,
#        15472.99864013, 15256.53075531, 16316.79475682, 14778.5651608 ,
#        14545.89025829, 14553.41033899, 14213.54290571, 13634.629314  ,
#        13484.36132904, 13670.39183791, 13603.72127119, 13608.61188677,
#        13217.30645275, 13012.01099824, 13282.84105609, 13531.96546385,
#        13596.62376707, 13510.58256083, 13650.29042193, 13664.0441785 ,
#        13353.32541993, 13201.65903009, 13405.10514751, 13320.74516451,
#        13429.18498747, 13638.89202706, 14471.05899467, 14098.12674859,
#        14085.8410813 , 13806.32634291, 13853.78826155, 14500.99092492,
#        15175.92232645, 15553.97477005, 15854.83446016, 15077.98158137,
#        15639.0974942 , 14931.98702442, 15209.01233936, 15474.52600295,
#        15068.85277171, 15654.01048888, 15937.82822929, 16169.37218906,
#        16449.78567799, 17248.67172771, 17620.74300369, 17580.24340467,
#        17921.42052123, 19185.84263705, 19275.55582537, 18699.87701948,
#        18723.05928626, 18374.13584328, 18275.61962692, 17870.90438578,
#        17847.07897219, 17638.38956563, 17617.90634525, 16963.2943176 ,
#        18294.05007374, 17505.10972832, 17589.33689463, 17570.93556172,
#        17414.86910818, 17392.03055708, 17769.45901226, 17344.3857237 ,
#        17416.59654595, 16675.49596121, 15880.78125195, 15475.31500372,
#        15692.97855356, 15898.14559288, 15465.20430148, 15125.56632654,
#        15096.44692458, 14984.21772942, 15232.98442365, 15455.65491479,
#        15801.7237703 , 15726.40787284, 15966.97261482, 15631.3539128 ,
#        15873.30859706, 16305.82242203, 16627.73135941, 16866.9581335 ,
#        16358.87872946, 16782.43319815, 16589.74472452, 16729.5458983 ,
#        17044.75733896, 16824.43319007, 17419.56752273, 18094.56210074,
#        17751.03912987, 18213.58883518, 18455.00785703, 18030.98661434,
#        17537.93278089, 17808.57965801, 17861.30562309, 18525.5045212 ,
#        18965.45234404, 18925.23885486, 18545.84807722, 20889.18507013,
#        22085.44091377, 22381.86668304, 22392.84922608, 22161.2204477 ,
#        24200.61966882, 24969.66053569, 25032.85765661, 24757.5853483 ,
#        24470.54896551, 23922.28377041, 23036.62566839, 22561.29735856,
#        22132.48579121, 21221.05861909, 21105.08728205, 20675.27089628,
#        20401.98793028, 19516.01981123, 18187.32866718, 17789.91885646,
#        16879.24410984, 16688.47694194, 16744.25096188, 16807.25318773])

# %%
test_index=test.index
y_test_pred=predictions
y_test_pred=pd.DataFrame(columns=['AQ'],data=y_test_pred)

# %%
y_test_pred
# Out:
#                AQ
# 0    15747.413721
# 1    16112.778420
# 2    16363.004988
# 3    16735.314367
# 4    16806.185057
# 5    16717.780038
# 6    16582.237973
# 7    16463.187834
# 8    16551.018145
# 9    16457.211384
# 10   16495.179880
# 11   16333.643071
# 12   16266.232968
# 13   16162.550397
# 14   16082.329499
# 15   16341.523731
# 16   16275.365027
# 17   15753.473125
# 18   15646.841621
# 19   15605.201801
# 20   15783.888039
# 21   15831.981682
# 22   15323.555455
# 23   15045.976114
# 24   15306.800705
# 25   15228.415682
# 26   15238.976398
# 27   15254.720223
# 28   15287.763797
# 29   15282.752212
# 30   15263.969414
# 31   15226.574053
# 32   15268.995218
# 33   15264.451919
# 34   15027.471587
# 35   15017.169027
# 36   15269.371363
# 37   15494.257663
# 38   15376.162926
# 39   15494.228378
# 40   15231.887151
# 41   15119.924023
# 42   15062.065828
# 43   15091.015584
# 44   15314.503346
# 45   15517.646912
# 46   15642.538479
# 47   15708.309546
# 48   15761.945127
# 49   15876.506968
# 50   16484.578948
# 51   15963.499921
# 52   16119.632452
# 53   16151.395540
# 54   15965.542277
# 55   15885.052676
# 56   16128.485182
# 57   16212.002329
# 58   16039.876623
# 59   16619.289499
# 60   16608.887336
# 61   16038.901812
# 62   16040.173285
# 63   15797.271228
# 64   15688.295434
# 65   15637.021466
# 66   15318.023714
# 67   15327.618730
# 68   15149.492172
# 69   14860.111233
# 70   14856.108530
# 71   14954.984540
# 72   14935.112248
# 73   15045.714144
# 74   14924.734024
# 75   14909.927810
# 76   14998.849470
# 77   15037.520717
# 78   15048.136737
# 79   14690.665039
# 80   14606.430928
# 81   14973.426976
# 82   14918.753856
# 83   14846.450781
# 84   15181.659852
# 85   15260.840727
# 86   14733.017985
# 87   14953.755095
# 88   14911.981675
# 89   14823.383464
# 90   14911.851110
# 91   14813.250035
# 92   15001.044612
# 93   15216.345333
# 94   15352.060333
# 95   15409.243566
# 96   15287.759411
# 97   15634.881777
# 98   15448.267432
# 99   15350.995167
# 100  15840.098074
# 101  16022.347723
# 102  15876.171339
# 103  15909.529578
# 104  15983.560083
# 105  16159.973120
# 106  16499.129793
# 107  16971.356105
# 108  17126.059219
# 109  16888.795816
# 110  16633.148685
# 111  16275.820944
# 112  16375.839638
# 113  15745.353580
# 114  15323.564098
# 115  14896.402219
# 116  15601.126256
# 117  14560.926142
# 118  14444.936697
# 119  14228.431929
# 120  14159.335616
# 121  14124.558551
# 122  14055.542972
# 123  13911.831670
# 124  14012.932589
# 125  15619.279974
# 126  14111.497419
# 127  15027.723373
# 128  13900.462276
# 129  13720.735357
# 130  13557.678983
# 131  13573.370458
# 132  13733.590232
# 133  13869.305814
# 134  13803.719206
# 135  13825.900229
# 136  14087.973265
# 137  13856.585998
# 138  13815.878382
# 139  13674.032319
# 140  13142.629832
# 141  12472.198312
# 142  12414.613452
# 143  12482.578841
# 144  12913.876318
# 145  12762.868621
# 146  12617.964668
# 147  12509.105399
# 148  12471.445178
# 149  12477.600728
# 150  12456.092285
# 151  12452.221056
# 152  12456.255028
# 153  12487.314754
# 154  12580.293059
# 155  12484.201799
# 156  12612.166746
# 157  12736.381307
# 158  12829.882467
# 159  12871.014162
# 160  13011.533377
# 161  13028.273544
# 162  13062.400387
# 163  13352.856658
# 164  14139.474711
# 165  14375.194872
# 166  14778.492639
# 167  14372.677356
# 168  13614.525194
# 169  13640.147591
# 170  13683.094793
# 171  13640.532491
# 172  13715.752790
# 173  13950.062987
# 174  13217.599294
# 175  13248.281880
# 176  13159.412989
# 177  13579.418576
# 178  13541.771666
# 179  13446.390895
# 180  13387.517263
# 181  13084.272727
# 182  13299.791556
# 183  12919.181154
# 184  12812.299401
# 185  12789.884779
# 186  12667.723865
# 187  12565.145691
# 188  12690.931332
# 189  12684.918827
# 190  12544.022884
# 191  12459.958459
# 192  12357.237507
# 193  12277.390150
# 194  12234.944775
# 195  12193.159702
# 196  12151.031806
# 197  12182.215303
# 198  12145.490212
# 199  12144.000577
# 200  12090.908129
# 201  11850.261801
# 202  12017.676327
# 203  11937.669457
# 204  11893.939873
# 205  11887.720888
# 206  11882.622472
# 207  11870.241204
# 208  11863.978233
# 209  11964.797496
# 210  11875.151675
# 211  11861.772653
# 212  11836.868088
# 213  11882.014420
# 214  11791.187695
# 215  11842.778319
# 216  11890.021412
# 217  11962.027868
# 218  12055.037019
# 219  12042.534234
# 220  11859.417692
# 221  11853.720606
# 222  11855.272012
# 223  11888.771976
# 224  12076.748733
# 225  12074.590380
# 226  12193.119447
# 227  12286.949830
# 228  12214.093791
# 229  12270.365499
# 230  12301.497359
# 231  12438.592418
# 232  12698.268752
# 233  12579.711927
# 234  12418.429236
# 235  12443.926175
# 236  12461.458671
# 237  12660.499290
# 238  12613.760894
# 239  12694.627532
# 240  12588.508137
# 241  12486.678669
# 242  12568.250810
# 243  12673.187438
# 244  12677.882384
# 245  12743.337041
# 246  12589.427474
# 247  12607.530914
# 248  12537.257709
# 249  12516.409400
# 250  12466.238032
# 251  12438.962827
# 252  12384.264345
# 253  12480.124345
# 254  12701.076532
# 255  12887.569867
# 256  12538.356416
# 257  12749.532844
# 258  12845.036809
# 259  12636.262959
# 260  12685.287068
# 261  12639.055222
# 262  12710.519833
# 263  12789.320977
# 264  12825.641484
# 265  12774.957057
# 266  12769.854418
# 267  12847.122528
# 268  12899.692185
# 269  12951.319397
# 270  12818.449193
# 271  12846.341929
# 272  12683.312560
# 273  12614.990193
# 274  12652.414514
# 275  12662.393876
# 276  12667.211160
# 277  12671.894837
# 278  12713.672533
# 279  12631.357310
# 280  12707.049085
# 281  12798.764056
# 282  12809.202220
# 283  12772.487672
# 284  12904.909401
# 285  13046.777084
# 286  13039.624448
# 287  13128.013662
# 288  13157.700899
# 289  13214.563920
# 290  13267.610002
# 291  13445.853895
# 292  13768.530048
# 293  13994.767094
# 294  13945.569143
# 295  13994.348315
# 296  14053.634848
# 297  14109.561683
# 298  14136.586457
# 299  13728.921012
# 300  13511.559812
# 301  13295.616644
# 302  13309.622973
# 303  13308.023134
# 304  13422.501164
# 305  13361.131167
# 306  13136.679546
# 307  13181.480822
# 308  13457.621139
# 309  13442.244673
# 310  13478.960965
# 311  13501.903398
# 312  13786.094003
# 313  13750.182297
# 314  13727.623536
# 315  14057.423602
# 316  13778.669169
# 317  13881.873721
# 318  13933.821775
# 319  14000.627088
# 320  13905.019521
# 321  13878.756530
# 322  13699.530459
# 323  13593.450459
# 324  13932.488612
# 325  14036.820049
# 326  14072.817966
# 327  14299.814110
# 328  14226.266194
# 329  13820.936667
# 330  13303.091563
# 331  13507.221442
# 332  13572.002920
# 333  13195.643024
# 334  13146.980875
# 335  13535.578822
# 336  13269.185440
# 337  13704.256363
# 338  14439.950470
# 339  14936.815448
# 340  15506.056134
# 341  15050.691395
# 342  15760.998453
# 343  16029.322127
# 344  16293.125423
# 345  16000.204441
# 346  15641.731544
# 347  15449.204533
# 348  15472.998640
# 349  15256.530755
# 350  16316.794757
# 351  14778.565161
# 352  14545.890258
# 353  14553.410339
# 354  14213.542906
# 355  13634.629314
# 356  13484.361329
# 357  13670.391838
# 358  13603.721271
# 359  13608.611887
# 360  13217.306453
# 361  13012.010998
# 362  13282.841056
# 363  13531.965464
# 364  13596.623767
# 365  13510.582561
# 366  13650.290422
# 367  13664.044179
# 368  13353.325420
# 369  13201.659030
# 370  13405.105148
# 371  13320.745165
# 372  13429.184987
# 373  13638.892027
# 374  14471.058995
# 375  14098.126749
# 376  14085.841081
# 377  13806.326343
# 378  13853.788262
# 379  14500.990925
# 380  15175.922326
# 381  15553.974770
# 382  15854.834460
# 383  15077.981581
# 384  15639.097494
# 385  14931.987024
# 386  15209.012339
# 387  15474.526003
# 388  15068.852772
# 389  15654.010489
# 390  15937.828229
# 391  16169.372189
# 392  16449.785678
# 393  17248.671728
# 394  17620.743004
# 395  17580.243405
# 396  17921.420521
# 397  19185.842637
# 398  19275.555825
# 399  18699.877019
# 400  18723.059286
# 401  18374.135843
# 402  18275.619627
# 403  17870.904386
# 404  17847.078972
# 405  17638.389566
# 406  17617.906345
# 407  16963.294318
# 408  18294.050074
# 409  17505.109728
# 410  17589.336895
# 411  17570.935562
# 412  17414.869108
# 413  17392.030557
# 414  17769.459012
# 415  17344.385724
# 416  17416.596546
# 417  16675.495961
# 418  15880.781252
# 419  15475.315004
# 420  15692.978554
# 421  15898.145593
# 422  15465.204301
# 423  15125.566327
# 424  15096.446925
# 425  14984.217729
# 426  15232.984424
# 427  15455.654915
# 428  15801.723770
# 429  15726.407873
# 430  15966.972615
# 431  15631.353913
# 432  15873.308597
# 433  16305.822422
# 434  16627.731359
# 435  16866.958133
# 436  16358.878729
# 437  16782.433198
# 438  16589.744725
# 439  16729.545898
# 440  17044.757339
# 441  16824.433190
# 442  17419.567523
# 443  18094.562101
# 444  17751.039130
# 445  18213.588835
# 446  18455.007857
# 447  18030.986614
# 448  17537.932781
# 449  17808.579658
# 450  17861.305623
# 451  18525.504521
# 452  18965.452344
# 453  18925.238855
# 454  18545.848077
# 455  20889.185070
# 456  22085.440914
# 457  22381.866683
# 458  22392.849226
# 459  22161.220448
# 460  24200.619669
# 461  24969.660536
# 462  25032.857657
# 463  24757.585348
# 464  24470.548966
# 465  23922.283770
# 466  23036.625668
# 467  22561.297359
# 468  22132.485791
# 469  21221.058619
# 470  21105.087282
# 471  20675.270896
# 472  20401.987930
# 473  19516.019811
# 474  18187.328667
# 475  17789.918856
# 476  16879.244110
# 477  16688.476942
# 478  16744.250962
# 479  16807.253188

# %%
y_test
# Out:
#               AQ
# 0    18013.42543
# 1    18015.00235
# 2    17894.22786
# 3    17738.59662
# 4    17398.49838
# 5    17012.86840
# 6    16667.82936
# 7    16784.20350
# 8    16699.46087
# 9    16527.75824
# 10   16476.48936
# 11   16460.38027
# 12   16134.57818
# 13   16413.48709
# 14   16770.93418
# 15   16767.17196
# 16   16686.58994
# 17   16044.64998
# 18   15635.34780
# 19   15678.60462
# 20   15623.33072
# 21   15785.76972
# 22   15384.10014
# 23   14984.32190
# 24   15316.01060
# 25   15314.09475
# 26   15319.97880
# 27   15058.69797
# 28   14857.75494
# 29   14808.54663
# 30   14674.30258
# 31   14589.17892
# 32   14745.52080
# 33   14758.09466
# 34   14892.18016
# 35   14899.87875
# 36   14937.04446
# 37   14822.02380
# 38   15022.48875
# 39   15368.82630
# 40   15566.88490
# 41   15896.85593
# 42   16471.58820
# 43   16863.63870
# 44   16952.70577
# 45   17081.88006
# 46   17299.48224
# 47   17096.32635
# 48   17100.80865
# 49   16903.55674
# 50   16706.38830
# 51   16592.52392
# 52   16396.19705
# 53   16261.46688
# 54   15727.77374
# 55   15524.38670
# 56   15180.51408
# 57   14999.95920
# 58   15182.39430
# 59   14983.53536
# 60   14851.54671
# 61   14762.47296
# 62   14885.74935
# 63   15073.41344
# 64   15109.77816
# 65   15110.60484
# 66   15048.23312
# 67   14681.86580
# 68   14354.34138
# 69   14131.41444
# 70   14193.54937
# 71   14223.08940
# 72   14442.62894
# 73   14230.49198
# 74   14099.57549
# 75   13867.34349
# 76   13812.68950
# 77   14088.40056
# 78   14093.50650
# 79   14142.57327
# 80   14180.33456
# 81   14122.67205
# 82   13965.43148
# 83   13991.63010
# 84   13778.56956
# 85   13989.50955
# 86   13841.66007
# 87   13837.41873
# 88   13960.43302
# 89   13832.83888
# 90   13887.86980
# 91   13959.64570
# 92   14177.12416
# 93   14208.47631
# 94   14309.51502
# 95   14175.96126
# 96   14585.49186
# 97   15076.80810
# 98   15622.09611
# 99   15865.20891
# 100  16507.89664
# 101  16844.03721
# 102  17204.21703
# 103  17666.74296
# 104  17647.05366
# 105  17471.94057
# 106  17452.78590
# 107  17174.44632
# 108  17005.63152
# 109  16441.38134
# 110  15731.33562
# 111  15404.57721
# 112  15349.44958
# 113  15132.73596
# 114  14746.93430
# 115  14555.90738
# 116  14380.87392
# 117  14431.14050
# 118  14559.53650
# 119  14689.69524
# 120  14637.15694
# 121  14180.70510
# 122  13813.88350
# 123  13536.20334
# 124  13479.81225
# 125  13438.90764
# 126  13471.82459
# 127  13136.74011
# 128  13158.84516
# 129  13072.38284
# 130  13109.88744
# 131  13100.32684
# 132  13039.38255
# 133  12887.66068
# 134  12732.84486
# 135  12653.08425
# 136  12296.70730
# 137  12265.25555
# 138  12310.15455
# 139  12062.24676
# 140  13290.90984
# 141  11411.83149
# 142  11145.44368
# 143  11263.92620
# 144  11284.59374
# 145  11253.87263
# 146  11196.60372
# 147  11292.55634
# 148  11295.79290
# 149  11241.41050
# 150  11256.71232
# 151  11266.48883
# 152  11220.79410
# 153  11319.53704
# 154  11241.01536
# 155  11358.62395
# 156  11504.99350
# 157  11767.23230
# 158  11856.84636
# 159  12118.34832
# 160  12326.77640
# 161  12854.71345
# 162  13282.30774
# 163  13400.06300
# 164  13955.16870
# 165  14002.28310
# 166  14041.22112
# 167  13911.41766
# 168  13997.33880
# 169  15946.91226
# 170  16543.06008
# 171  16506.30209
# 172  16642.92630
# 173  16729.45120
# 174  16634.55204
# 175  16266.92067
# 176  15669.81360
# 177  15429.25605
# 178  15076.68822
# 179  14846.45295
# 180  14332.99490
# 181  13798.05305
# 182  13650.30844
# 183  13393.12245
# 184  13320.14090
# 185  13236.44484
# 186  13248.02096
# 187  13021.11165
# 188  12899.59280
# 189  12591.07850
# 190  12483.21354
# 191  12228.61890
# 192  11927.89640
# 193  11898.30816
# 194  13546.46730
# 195  12918.42552
# 196  12471.97176
# 197  12313.28898
# 198  12445.46775
# 199  12302.91630
# 200  12233.88894
# 201  12084.83220
# 202  12175.15299
# 203  12099.82284
# 204  12087.15724
# 205  12117.75714
# 206  12006.94348
# 207  11994.77820
# 208  12042.61608
# 209  12044.98656
# 210  11991.84996
# 211  12126.57550
# 212  12165.13269
# 213  12143.96904
# 214  12190.43220
# 215  12122.30556
# 216  12136.42118
# 217  12219.15783
# 218  12190.61985
# 219  12119.58226
# 220  12131.36649
# 221  12157.21512
# 222  12088.82052
# 223  12267.43562
# 224  12233.55889
# 225  12416.73676
# 226  12763.19335
# 227  12860.58216
# 228  13152.04479
# 229  13195.44940
# 230  13379.93078
# 231  13384.28514
# 232  13481.44092
# 233  13515.27180
# 234  13689.78096
# 235  13572.74198
# 236  13636.44846
# 237  13630.12651
# 238  13650.40874
# 239  13590.20670
# 240  13555.34161
# 241  13643.41624
# 242  13495.90956
# 243  13500.58080
# 244  13609.38064
# 245  13675.95960
# 246  13485.44160
# 247  13431.50500
# 248  13506.58695
# 249  13449.96657
# 250  13541.85220
# 251  13539.94642
# 252  13620.83535
# 253  13541.03541
# 254  13493.60289
# 255  13634.70498
# 256  13593.00960
# 257  13702.30084
# 258  13570.50548
# 259  13522.98234
# 260  13562.61615
# 261  13656.67908
# 262  13573.28902
# 263  13592.09432
# 264  13635.03275
# 265  13580.70416
# 266  13725.34088
# 267  13698.63624
# 268  13731.38672
# 269  13741.65645
# 270  13670.08643
# 271  13683.81867
# 272  13601.96840
# 273  13709.35398
# 274  13625.59420
# 275  13729.84776
# 276  13606.41792
# 277  13592.31240
# 278  13673.70282
# 279  13607.93844
# 280  13741.44540
# 281  13675.11496
# 282  13781.53777
# 283  13738.85388
# 284  13726.06480
# 285  13780.69352
# 286  13826.42521
# 287  13745.67810
# 288  13889.02476
# 289  13858.55734
# 290  13829.22640
# 291  13969.33472
# 292  13845.03834
# 293  13982.75595
# 294  13883.94726
# 295  13825.17424
# 296  13884.99038
# 297  13802.23395
# 298  13872.41808
# 299  13878.38670
# 300  13853.44603
# 301   6893.43550
# 302  13834.13202
# 303  12812.63732
# 304  13795.69560
# 305  10357.14507
# 306  13949.28654
# 307  13906.05435
# 308  13870.40700
# 309  13810.68990
# 310  13711.05522
# 311  13751.45324
# 312  13883.48962
# 313  14056.39230
# 314  14204.66228
# 315  14197.57339
# 316  14290.33362
# 317  14244.31428
# 318  14228.24970
# 319  14225.30265
# 320  14138.89275
# 321  13904.94963
# 322  13835.50572
# 323  13778.71866
# 324  13685.70933
# 325  13615.28518
# 326  13633.01788
# 327  13619.38698
# 328  13640.98054
# 329  13718.11780
# 330  13860.87926
# 331  13905.31536
# 332  14167.37292
# 333  14168.86965
# 334  14227.07868
# 335  14241.38860
# 336  14278.00374
# 337  14244.19115
# 338  17109.07380
# 339  17423.03652
# 340  17932.62630
# 341  18520.82232
# 342  19280.13490
# 343  19718.87762
# 344  19697.60805
# 345  19406.54480
# 346  18801.20316
# 347  18067.54427
# 348  17716.99636
# 349  17092.45658
# 350  16550.06865
# 351  15656.83358
# 352  15260.91044
# 353  14819.44045
# 354  14762.61600
# 355  14585.67110
# 356  13935.54051
# 357  13272.32748
# 358  13276.25166
# 359  13338.95010
# 360  13353.58024
# 361  13256.52021
# 362  13241.57591
# 363  13146.81114
# 364  13083.94007
# 365  13116.84374
# 366  13126.80120
# 367  13107.34048
# 368  12959.96196
# 369  13067.73360
# 370  13082.28922
# 371  13073.83419
# 372  13228.70447
# 373  13453.03840
# 374  13634.78746
# 375  13846.22991
# 376  13921.02964
# 377  14185.56139
# 378  14425.59100
# 379  14625.74113
# 380  14808.98616
# 381  15245.28005
# 382  15749.92785
# 383  15948.57615
# 384  16672.67944
# 385  17054.11468
# 386  17264.14173
# 387  17679.10310
# 388  18067.21092
# 389  18452.68425
# 390  18596.73432
# 391  18646.17120
# 392  18244.76775
# 393  18173.91932
# 394  17934.25494
# 395  17925.93696
# 396  17471.61752
# 397  17332.59575
# 398  17481.35684
# 399  17496.04014
# 400  17158.55610
# 401  16469.26425
# 402  16004.91676
# 403  15626.85366
# 404  15798.19382
# 405  15337.48908
# 406  15356.37226
# 407  15099.79436
# 408  15000.00986
# 409  14885.15994
# 410  14943.40716
# 411  14831.12028
# 412  14789.58828
# 413  14818.50073
# 414  14895.03060
# 415  14576.92763
# 416  14420.64788
# 417  14427.33774
# 418  14286.80912
# 419  14187.82918
# 420  14192.96283
# 421  14094.94362
# 422  13944.61488
# 423  13928.52058
# 424  13780.13310
# 425  13922.28728
# 426  13972.80303
# 427  13979.52324
# 428  14115.31678
# 429  14018.93594
# 430  13948.90500
# 431  14001.71262
# 432  14565.22020
# 433  14754.57172
# 434  15236.90168
# 435  15481.67460
# 436  15782.94722
# 437  15825.79974
# 438  16000.99299
# 439  16086.50968
# 440  16133.83548
# 441  16158.88955
# 442  16982.81606
# 443  17430.49140
# 444  18039.52704
# 445  18335.03937
# 446  18600.80680
# 447  18488.21770
# 448  18138.87985
# 449  18164.77970
# 450  18191.29191
# 451  18141.78525
# 452  18157.70017
# 453  18070.82460
# 454  18068.84988
# 455  20923.03470
# 456  26409.40416
# 457  26986.25662
# 458  26979.65244
# 459  26662.68605
# 460  26069.03744
# 461  25628.47546
# 462  24315.39222
# 463  23586.63307
# 464  23059.56653
# 465  22486.01355
# 466  21907.90910
# 467  21444.28042
# 468  20795.76852
# 469  20285.90052
# 470  19907.01974
# 471  19576.37416
# 472  19585.58298
# 473  19338.39922
# 474  17763.79710
# 475  13576.71833
# 476  13548.77814
# 477  14428.75349
# 478  15040.21473
# 479  15779.09570

# %%
import seaborn as sns
sns.set(context='paper', style='ticks')

fig,axes=plt.subplots(2,1,figsize=(15,16))
ax1=axes[0]
ax2=axes[1]
fig.subplots_adjust(left=0.1, right=0.8, bottom=0.1, top=0.9, wspace=0.2, hspace=0.3)


x=test_index
y1=y_test['AQ']
y2=y_test_pred['AQ']
lns1=ax1.plot(x,y1,label='y_test',marker='v',markevery=1, color='lightcoral')
lns2=ax1.plot(x,y2,label='y_test_pred',marker='D',markevery=1, color='dodgerblue')
ax1.tick_params(labelsize=12)
ax1.set_xlim(0,480,1)
ax1.set_ylim(6000,30000, 2000)
ax1.set_xlabel('Timeindex(8h)',size=20)
ax1.set_ylabel('AQ(m³/h)',size=20)
ax1.set_title('m7_ridge',size=20,fontweight='bold',loc='left')
lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=1,fontsize=12,ncol=2,frameon=False)

# %%
# plt.figure(figsize=(15,8))
# ax=plt.axes()
# plt_x=test['time'].to_numpy()
#     # .to_datetime().apply(lambda x: x.strftime('%Y-%m-%d'))
# print(type(plt_x))
# plt_y1=test[Y_columns].to_numpy()
# print(type(plt_y1))
# plt_y2=predictions
# print(type(plt_y2))
#
# plt.ylim(0, 30000)
# ax.plot(plt_x, plt_y1,color='r', marker='*', linestyle = '-.', lw=2, label='true') #‘s’ : 方块状
# ax.plot(plt_x, plt_y2,color='g', marker='o', linestyle = '-.', lw=2, label='predictions')

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import r2_score as r2

loss=mape(y1, y2)
r2loss=r2(y1, y2)

print(f'MAPE: {loss} , R2 {r2loss}')
# Out:
# MAPE: 0.06446066371200204 , R2 0.7301482789525083

# %%
feature_mean= feature_importance_df[["Feature", "importance"]].groupby("Feature").mean().sort_values(by="importance", ascending=False)[:20].reset_index()
# print(feature_mean)
import seaborn as sns
plt.figure(figsize=(15,8))
sns.barplot(x="importance",
            y="Feature",
            data=feature_mean)
# plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('fig8.tiff',dpi=400)

# %%
frame=pd.DataFrame()
frame['ytest']=y_test_pred
frame.to_excel('../secondgoaldata/m9_LGBM.xlsx')
